# %%
import train_new_loss
# Out:
# RUN_SAVE_NAME = 'Vae_h500_l2'
# torch.Size([500, 784])
# torch.Size([500])
# torch.Size([3, 500])
# torch.Size([3])
# torch.Size([3, 500])
# torch.Size([3])
# torch.Size([500, 3])
# torch.Size([500])
# torch.Size([784, 500])
# torch.Size([784])
# [Parameter containing:
# tensor([[ 0.0340,  0.0234, -0.0275,  ...,  0.0332, -0.0319,  0.0099],
#         [-0.0243,  0.0196,  0.0321,  ..., -0.0254,  0.0074, -0.0030],
#         [ 0.0019,  0.0292, -0.0152,  ..., -0.0060,  0.0317,  0.0013],
#         ...,
#         [ 0.0304,  0.0330, -0.0080,  ...,  0.0024, -0.0057, -0.0233],
#         [-0.0055, -0.0154,  0.0346,  ...,  0.0166, -0.0188,  0.0247],
#         [-0.0326,  0.0338,  0.0161,  ..., -0.0067,  0.0084, -0.0005]],
#        requires_grad=True), Parameter containing:
# tensor([-3.1733e-02, -1.2260e-02, -2.7115e-03, -3.4492e-02, -3.2752e-02,
#          8.1437e-03,  2.0527e-02, -2.6567e-03, -1.6126e-02, -3.4527e-02,
#         -8.0313e-03, -2.9656e-02,  2.0560e-02, -1.3409e-02, -4.6490e-03,
# ...
