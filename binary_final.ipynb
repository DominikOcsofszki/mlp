# %%
import model
import helper
import MyDataSet

MyDataSets_Subset = MyDataSet.MyDataSets_Subset()
# Out:
# MyDataSets.MyDataSets_Subset.__init__
# [   0    1    2 ... 9997 9998 9999]
# self.train_loader_subset_size = 11791
# self.train_loader_subset_size = 11791
# self.train_loader_subset = <torch.utils.data.dataloader.DataLoader object at 0x15747ded0>
# self.test_loader_subset_size = 1991

# %%
import helper# model_loaded = model.VaeMe_500_hidden()
import model
import torch
pick_model = model.VaeFinal_only_one_hidden()
pick_model = helper.import_model_name(model_x=pick_model, activate_eval=True)

max = -1.25
min = -.5
rand_tensor = (max-min)*torch.rand((1, 2)) + min
print(rand_tensor)

helper.latent_rand_to_img(pick_model,rand_tensor)
# Out:
# model_name = 'VaeFinal_only_one_hidden'
# VaeFinal_only_one_hidden_weights imported
# tensor([[-0.6002, -0.9643]])

# %%
helper.show_scatter_with_batch_from_iter(model=pick_model, batch_from_dataloader_iter=MyDataSets_Subset.dataloader_test_subset_one_batch(),current_epoch='')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 helper.show_scatter_with_batch_from_iter(model=pick_model, batch_from_dataloader_iter=MyDataSets_Subset.dataloader_test_subset_one_batch(),current_epoch='')
#
# NameError: name 'MyDataSets_Subset' is not defined

# %%
from torchvision.utils import make_grid
from MyDataSet import MyDataSets_Subset_4_9
from matplotlib import pyplot as plt
import numpy as np
# Display original images
mydatasets_subset_4_9 = MyDataSets_Subset_4_9(batch_size_train=10000)

test_images_org, _ = mydatasets_subset_4_9.dataloader_test_subset_one_batch()
test_images_copy = test_images_org.clone()
with torch.no_grad():
    print("Original Images")
    test_images = test_images_copy.cpu()
    test_images = test_images.clamp(0, 1)
    test_images = test_images[:50]
    test_images = make_grid(test_images, 10, 5)
    test_images = test_images.numpy()
    test_images = np.transpose(test_images, (1, 2, 0))
    plt.imshow(test_images)
    plt.show()
# Out:
# MyDataSets.MyDataSets_Subset_4_9.__init__
# self.train_loader_subset_changed_labels_size = 11791
# self.train_loader_subset_changed_labels_size = 11791
# self.train_loader_subset_changed_labels = <torch.utils.data.dataloader.DataLoader object at 0x16d1fe8f0>
# self.test_loader_subset_changed_labels_size = 1991
# self.test_loader_subset_changed_labels = <torch.utils.data.dataloader.DataLoader object at 0x16d1fece0>
# Original Images

# %%
# Display reconstructed images
import helper# model_loaded = model.VaeMe_500_hidden()
import model
import torch
pick_model = model.VaeFinal_only_one_hidden()
pick_model = helper.import_model_name(model_x=pick_model, activate_eval=True)
print(test_images_org.shape)
reconstructions = pick_model(test_images_org)[0]
print(reconstructions)
with torch.no_grad():
    print("Reconstructions")
    reconstructions = reconstructions.view(reconstructions.size(0), 1, 28, 28)
    reconstructions = reconstructions.cpu()
    reconstructions = reconstructions.clamp(0, 1)
    reconstructions = reconstructions[:50]
    plt.imshow(np.transpose(make_grid(reconstructions, 10, 5).numpy(), (1, 2, 0)))
    plt.show()
# Out:
# model_name = 'VaeFinal_only_one_hidden'
# VaeFinal_only_one_hidden_weights imported
# torch.Size([1991, 1, 28, 28])
# tensor([[ 3.3885e-03,  2.5951e-03, -1.4589e-04,  ...,  8.8211e-05,
#           2.6405e-03,  1.3720e-03],
#         [ 3.2286e-03,  2.0481e-03, -6.6291e-04,  ...,  1.7018e-03,
#           8.5015e-04,  1.8811e-03],
#         [ 3.3423e-03, -8.0218e-04, -3.7597e-03,  ...,  3.9248e-03,
#          -1.6818e-03, -3.9892e-04],
#         ...,
#         [ 2.2045e-03, -8.0053e-04, -4.1453e-03,  ...,  1.1326e-03,
#           1.1386e-03, -2.2221e-03],
#         [ 5.1992e-03, -2.5686e-03,  1.0155e-03,  ..., -1.1657e-04,
#          -2.6103e-04, -3.9049e-04],
#         [ 1.9828e-04,  1.3798e-03,  4.8923e-04,  ..., -4.2221e-04,
#           5.7903e-05, -4.9469e-05]], grad_fn=<AddmmBackward0>)
# Reconstructions

# %%
from matplotlib import pyplot as plt
import numpy as np
from torchvision.utils import make_grid
from MyDataSet import MyDataSets_Subset_4_9
from matplotlib import pyplot as plt
import numpy as np
import torch
# Display original images
mydatasets_subset_4_9 = MyDataSets_Subset_4_9(batch_size_train=10000)

test_images_org, _ = mydatasets_subset_4_9.dataloader_test_subset_one_batch()
test_images_copy = test_images_org.clone()
with torch.no_grad():
    print("Original Images")
    test_images = test_images_copy.cpu()
    test_images = test_images.clamp(0, 1)
    test_images = test_images[:50]
    test_images = make_grid(test_images, 10, 5)
    test_images = test_images.numpy()
    test_images = np.transpose(test_images, (1, 2, 0))
    plt.imshow(test_images)
    plt.show()

# Display reconstructed images
import helper# model_loaded = model.VaeMe_500_hidden()
import model
import torch
pick_model = model.VaeFinal_only_one_hidden()
pick_model = helper.import_model_name(model_x=pick_model, activate_eval=True)
# print(test_images_org.shape)
reconstructions = pick_model(test_images_org)[0]
# print(reconstructions)
with torch.no_grad():
    print("Reconstructions")
    reconstructions = reconstructions.view(reconstructions.size(0), 1, 28, 28)
    reconstructions = reconstructions.cpu()
    reconstructions = reconstructions.clamp(0, 1)
    reconstructions = reconstructions[:50]
    plt.imshow(np.transpose(make_grid(reconstructions, 10, 5).numpy(), (1, 2, 0)))
    plt.show()
# Out:
# MyDataSets.MyDataSets_Subset_4_9.__init__
# Original Images
# Reconstructions

# %%
from matplotlib import pyplot as plt
import numpy as np
from torchvision.utils import make_grid
from MyDataSet import MyDataSets_Subset_4_9
from matplotlib import pyplot as plt
import numpy as np
import torch
# Display original images
mydatasets_subset_4_9 = MyDataSets_Subset_4_9(batch_size_train=10000)

test_images_org, _ = mydatasets_subset_4_9.dataloader_test_subset_one_batch()
test_images_copy = test_images_org.clone()
with torch.no_grad():
    print("Original Images")
    test_images = test_images_copy.cpu()
    test_images = test_images.clamp(0, 1)
    test_images = test_images[:50]
    test_images = make_grid(test_images, 10, 5)
    test_images = test_images.numpy()
    test_images = np.transpose(test_images, (1, 2, 0))
    plt.imshow(test_images)
    plt.show()

# Display reconstructed images
import helper# model_loaded = model.VaeMe_500_hidden()
import model
import torch
pick_model = model.VaeFinal_only_one_hidden()
pick_model = helper.import_model_name(model_x=pick_model, activate_eval=True)
# print(test_images_org.shape)
reconstructions = pick_model(test_images_org)[0]
# print(reconstructions)
with torch.no_grad():
    print("Reconstructions")
    reconstructions = reconstructions.view(reconstructions.size(0), 1, 28, 28)
    reconstructions = reconstructions.cpu()
    reconstructions = reconstructions.clamp(0, 1)
    reconstructions = reconstructions[:50]
    plt.imshow(np.transpose(make_grid(reconstructions, 10, 5).numpy(), (1, 2, 0)))
    plt.show()
# Out:
# MyDataSets.MyDataSets_Subset_4_9.__init__
# Original Images
# Reconstructions

# %%
import helper# model_loaded = model.VaeMe_500_hidden()
import model
import torch
pick_model = model.Vae_var_fix_norm()
pick_model = helper.import_model_name(model_x=pick_model, activate_eval=True)
helper.show_scatter(examples=10000, model_loaded=pick_model, lat=2,in_train_class=False)

# pick_model.eval()
# helper.latent_to_plt_img(pick_model,rand_lat_size=2)
rand_tensor = torch.rand(2)
# rand_tensor = torch.tensor([0.,0.])
helper.latent_rand_to_img(pick_model,rand_tensor)

# %%
from matplotlib import pyplot as plt
import numpy as np
from torchvision.utils import make_grid
from MyDataSet import MyDataSets_Subset_4_9
from matplotlib import pyplot as plt
import numpy as np
import torch
# Display original images
mydatasets_subset_4_9 = MyDataSets_Subset_4_9(batch_size_train=10000)

test_images_org, _ = mydatasets_subset_4_9.dataloader_test_subset_one_batch()
test_images_copy = test_images_org.clone()
with torch.no_grad():
    print("Original Images")
    test_images = test_images_copy.cpu()
    test_images = test_images.clamp(0, 1)
    test_images = test_images[:50]
    test_images = make_grid(test_images, 10, 5)
    test_images = test_images.numpy()
    test_images = np.transpose(test_images, (1, 2, 0))
    plt.imshow(test_images)
    plt.show()

# Display reconstructed images
import helper# model_loaded = model.VaeMe_500_hidden()
import model
import torch
pick_model = model.Vae_var_fix_norm()
pick_model = helper.import_model_name(model_x=pick_model, activate_eval=True)
# print(test_images_org.shape)
reconstructions = pick_model(test_images_org)[0]
# print(reconstructions)
with torch.no_grad():
    print("Reconstructions")
    reconstructions = reconstructions.view(reconstructions.size(0), 1, 28, 28)
    reconstructions = reconstructions.cpu()
    reconstructions = reconstructions.clamp(0, 1)
    reconstructions = reconstructions[:50]
    plt.imshow(np.transpose(make_grid(reconstructions, 10, 5).numpy(), (1, 2, 0)))
    plt.show()
# Out:
# MyDataSets.MyDataSets_Subset_4_9.__init__
# Original Images
# Reconstructions

# %%
# helper.latent_rand_to_img(pick_model, rand_tensor)
from matplotlib import pyplot as plt
import numpy as np
from torchvision.utils import make_grid
from MyDataSet import MyDataSets_Subset_4_9
from matplotlib import pyplot as plt
import numpy as np
import torch
import model
import helper
# Display original images
mydatasets_subset_4_9 = MyDataSets_Subset_4_9(batch_size_train=10000)

test_images_org, _ = mydatasets_subset_4_9.dataloader_test_subset_one_batch()
test_images_copy = test_images_org.clone()
pick_model = model.VaeFinal_only_one_hidden()
pick_model = helper.import_model_name(model_x=pick_model, activate_eval=True)
# print(test_images_org.shape)
reconstructions = pick_model(test_images_org)[0]
print(reconstructions)
# Out:
# MyDataSets.MyDataSets_Subset_4_9.__init__
# tensor([[ 0.0030, -0.0079,  0.0058,  ..., -0.0015, -0.0115, -0.0085],
#         [-0.0024,  0.0022, -0.0032,  ..., -0.0021,  0.0007,  0.0006],
#         [-0.0009, -0.0012,  0.0039,  ..., -0.0025, -0.0024, -0.0021],
#         ...,
#         [-0.0017, -0.0010,  0.0010,  ..., -0.0017, -0.0049, -0.0003],
#         [-0.0012,  0.0021, -0.0019,  ..., -0.0033, -0.0033,  0.0014],
#         [-0.0008,  0.0018, -0.0011,  ..., -0.0022, -0.0002, -0.0011]],
#        grad_fn=<AddmmBackward0>)

# %%
def plot_reconstructed(autoencoder, r0=(-5, 10), r1=(-10, 5), n=12):
    w = 28
    img = np.zeros((n*w, n*w))
    for i, y in enumerate(np.linspace(*r1, n)):
        for j, x in enumerate(np.linspace(*r0, n)):
            z = torch.Tensor([[x, y]]).to('cpu')
            x_hat = autoencoder.decode(z)
            x_hat = x_hat.reshape(28, 28).to('cpu').detach().numpy()
            img[(n-1-i)*w:(n-1-i+1)*w, j*w:(j+1)*w] = x_hat
    plt.imshow(img, extent=[*r0, *r1])
plot_reconstructed(pick_model)

# %%
def plot_reconstructed(autoencoder, r0=(-5, 10), r1=(-10, 5), n=12):
    w = 28
    img = torch.tensor(np.zeros((n*w, n*w)))
    for i, y in enumerate(np.linspace(*r1, n)):
        for j, x in enumerate(np.linspace(*r0, n)):
            z = torch.Tensor([[x, y]]).to('cpu')
            x_hat = autoencoder.decode(z)
            # x_hat = x_hat.reshape(28, 28).to('cpu').detach().numpy()
            x_hat = x_hat.reshape(28, 28).to('cpu')
            img[(n-1-i)*w:(n-1-i+1)*w, j*w:(j+1)*w] = x_hat
        # plt.imshow(img, extent=[*r0, *r1])


        plt.imshow(np.transpose(make_grid(img, 10, 5).numpy(), (1, 2, 0)))
        plt.show()
plot_reconstructed(pick_model)

    # with torch.no_grad():
    #     print("Reconstructions")
    #     reconstructions = reconstructions.view(reconstructions.size(0), 1, 28, 28)
    #     reconstructions = reconstructions.cpu()
    #     reconstructions = reconstructions.clamp(0, 1)
    #     reconstructions = reconstructions[:50]
    #     plt.imshow(np.transpose(make_grid(reconstructions, 10, 5).numpy(), (1, 2, 0)))
    #     plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
randtorch = torch.randn(2)
print(randtorch)
z, mu, sigma = pick_model(randtorch)
plt.imshow(z.detach().numpy())
# Out:
# tensor([1.1562, 1.0861])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [28], in <cell line: 3>()
#       1 randtorch = torch.randn(2)
#       2 print(randtorch)
# ----> 3 z, mu, sigma = pick_model(randtorch)
#       4 plt.imshow(z.detach().numpy())
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/PycharmProjects/mlp/model.py:1855, in VaeFinal_only_one_hidden.forward(self, x)
#    1854 def forward(self, x):
# -> 1855     mu, sigma = self.encode(x)
#    1856     eps = torch.randn_like(sigma)  # == torch.randn_like(mu) == torch.randn_like(sigma)
#    1857     z = mu + sigma * eps
#
# File ~/PycharmProjects/mlp/model.py:1838, in VaeFinal_only_one_hidden.encode(self, x)
#    1837 def encode(self, x):
# -> 1838     x = self.flatten(x)
#    1839     x = self.activation(self.img_to_hidden(x))
#    1841     # mu = self.sigmoid(self.hidden_to_mu(x))   #TODO normalize to -4 and 4 but not 0,1!
#    1842     # sigma = self.sigmoid(self.hidden_to_sigma(x))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.10/site-packages/torch/nn/modules/flatten.py:46, in Flatten.forward(self, input)
#      45 def forward(self, input: Tensor) -> Tensor:
# ---> 46     return input.flatten(self.start_dim, self.end_dim)
#
# IndexError: Dimension out of range (expected to be in range of [-1, 0], but got 1)

# %%
import helper# model_loaded = model.VaeMe_500_hidden()
import model
import torch
pick_model = model.pick_model = model.VaeFinal_only_one_hidden()
pick_model = helper.import_model_name(model_x=pick_model, activate_eval=True)

max = 4
min = -4
rand_tensor = (max-min)*torch.rand((1, 2)) + min
print(rand_tensor)

helper.latent_rand_to_img(pick_model,rand_tensor)
# Out:
# tensor([[-1.1631, -0.6776]])

# %%
z = rand_tensor[0][0] + rand_tensor[0][1] * torch.rand_like(rand_tensor[1])
helper.latent_rand_to_img(pick_model,z)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 z = rand_tensor[0][0] + rand_tensor[0][1] * torch.rand_like(rand_tensor[1])
#       2 helper.latent_rand_to_img(pick_model,z)
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1
